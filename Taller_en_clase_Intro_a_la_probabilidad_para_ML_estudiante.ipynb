# %% [markdown]
# <a href="https://colab.research.google.com/github/Mardugo/ClaseMachineLearning/blob/main/Taller_en_clase_Intro_a_la_probabilidad_para_ML_estudiante.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=300
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.6
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
print(p)
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()
# Out:
# 0.6

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.6 son u= 0.6 var= 0.24
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.6 son u_est= 0.60128 var_est= 0.23974236160000004

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5

from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
b = binom.rvs(n, p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.binom.html#scipy.stats.binom
plt.plot(b)
plt.title(str(N)+" puntos distribuidos binomial con n "+ str(n)+" con p="+str(p))
plt.show()

# %%
print(n, p)
b.sort()
plt.plot(b)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()
# Out:
# 10 0.5

# %%
plt.hist(b, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con "+str(n)+" y con p="+str(p))
plt.show()
print(type(b))
avg=b.mean()
varest=b.var()
print("Los valores teoricos de la media y varianza para la binomial con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 4.99334 var_est= 2.5004556443999997

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.4

from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
g = geom.rvs(p, size=1000)

plt.plot(g)
plt.title(str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()

# %%
print( p)
g.sort()
plt.plot(g)
plt.title(str(N)+" puntos distribuidos geometrica ordenados con p="+str(p))
plt.show()
# Out:
# 0.4

# %%
plt.hist(g, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometrica con p="+str(p))
plt.show()
print(type(g))
avg=g.mean()
varest=g.var()
print("Los valores teoricos de la media y varianza para la geometrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la geometrica con p= 0.4 son u= 2.5 var= 3.749999999999999
# Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p= 0.4 son u_est= 2.484 var_est= 3.625744

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')

la = poisson.rvs(L, size=N)
plt.plot(la)
plt.title(str(N)+" puntos distribuidos Poisson con L= "+str(L))
plt.show()

# %%
print( L)
la.sort()
plt.plot(la)
plt.title(str(N)+" puntos distribuidos Poisson ordenados con L= "+str(p))
plt.show()
# Out:
# 5

# %%
plt.hist(la, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Poisson con p="+str(p))
plt.show()
print(type(la))
avg=la.mean()
varest=la.var()
print("Los valores teoricos de la media y varianza para la Posson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la Posson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la geometrica con p= 0.4 son u_est= 4.963 var_est= 4.749630999999999

# %%
#Binomial negativa con parametro p después de r fallos
r,p = 5 , 0.5

from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(r, p, moments='mvsk')
b = binom.rvs(r, p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.binom.html#scipy.stats.binom
plt.plot(b)
plt.title(str(N)+" puntos distribuidos binomial negativa con n "+ str(r)+" con p="+str(p))
plt.show()

# %%
print(r, p)
b.sort()
plt.plot(b)
plt.title(str(N)+" puntos distribuidos bernoulli negativa ordenados con p="+str(p))
plt.show()
# Out:
# 10 0.5

# %%
plt.hist(b, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial negativa con "+str(r)+" y con p="+str(p))
plt.show()
print(type(b))
avg=b.mean()
varest=b.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la binomial con p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5 son u_est= 2.433 var_est= 1.213511

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=10000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.9904830572215415 var_est= 0.24343895999254364

# %%
# Uniforme entre 0 y 255

ini=0
fin=255
from scipy.stats import uniform
mean, var, skew, kurt = uniform.stats(moments='mvsk',loc=ini,scale=fin)
unif = uniform.rvs (loc=ini,scale=fin, size=N)

plt.plot(unif)
plt.title(str(N)+" puntos distribuidos uniformente con media="+str(ini)+" y std="+str(fin))
plt.show()
unif.sort() #ordenamiento
plt.plot(unif)
plt.title(str(N)+" puntos distribuidos uniformente ordenados con u="+str(ini)+ " y std= "+str(fin))
plt.show()
plt.hist(unif, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniformente con u="+str(ini)+ " y std= "+str(fin))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de unif")
avg=unif.mean()
varest=unif.var()
print("Los valores teoricos de la media y varianza para la uniforme son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la uniforme son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 126.7767595080859 var_est= 5411.191670493089

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import expon

mean, var, skew, kurt = expon.stats(moments='mvsk',scale=1/L)
expo = expon.rvs(scale=1/L, size=N)

plt.plot(expo)
plt.title(str(N)+" puntos distribuidos exponencial con L= "+str(L))
plt.show()
expo.sort()
plt.plot(expo)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con L= "+str(L))
plt.show()
plt.hist(expo, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con L= "+str(L))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de expo")
avg=expo.mean()
varest=expo.var()
print("Los valores teoricos de la media y varianza para la exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de e
# Los valores teoricos de la media y varianza para la exponencial son u= 3.3333333333333335 var= 11.111111111111112
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.308643129021079 var_est= 10.705634680495262

# %%
#Chi cuadrada con K grados de libertad
K=3.0

from scipy.stats import chi2

mean, var, skew, kurt = chi2.stats(K, moments='mvsk')
chi = chi2.rvs(K, size=N)
plt.plot(chi)
plt.title(str(N)+" puntos distribuidos chi cuadrado con K= "+str(K))
plt.show()
chi.sort()
plt.plot(chi)
plt.title(str(N)+" puntos distribuidos chi cuadrado ordenados con K="+str(K))
plt.show()
plt.hist(chi, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrado con K="+str(K))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de chi")
avg=chi.mean()
varest=chi.var()
print("Los valores teoricos de la media y varianza para la chi cuadrado son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de chi
# Los valores teoricos de la media y varianza para la chi cuadrado son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 2.9894014308410797 var_est= 6.240842542895749

# %%
#Gamma con parametros k y theta t

k,t=2.54,0.43
from scipy.stats import gamma

mean, var, skew, kurt = gamma.stats(a =k ,scale=t, moments='mvsk')
gamm = gamma.rvs(a=k,scale=t, size=N)

plt.plot(gamm)
plt.title(str(N)+" puntos distribuidos gamma con K="+str(K))
plt.show()
gamm.sort()
plt.plot(gamm)
plt.title(str(N)+" puntos distribuidos gamma ordenados con K="+str(K))
plt.show()
plt.hist(gamm, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con K="+str(K))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de gamm")
avg=gamm.mean()
varest=gamm.var()
print("Los valores teoricos de la media y varianza para la gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de gamm
# Los valores teoricos de la media y varianza para la gamma son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.0841774484694897 var_est= 0.4588405200788101
